# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install efficient_apriori
# !{sys.executable} -m pip install fpgrowth_py
# Out:
# Requirement already satisfied: numpy in c:\users\ghosh\anaconda3\lib\site-packages (1.23.5)
# Collecting efficient_apriori
#   Downloading efficient_apriori-2.0.5-py3-none-any.whl (14 kB)
# Installing collected packages: efficient_apriori
# Successfully installed efficient_apriori-2.0.5
# Collecting fpgrowth_py
#   Downloading fpgrowth_py-1.0.0-py3-none-any.whl (5.6 kB)
# Installing collected packages: fpgrowth_py
# Successfully installed fpgrowth_py-1.0.0

# %%
from read_files import CreateDataset
import itertools
from copy import deepcopy
from efficient_apriori import apriori
from fpgrowth_py import fpgrowth
import time

AMAZON = "Amazon.csv"
BESTBUY = "BestBuy.csv"
KMART = "Kmart.csv"
NIKE = "Nike.csv"
WALMART = "Walmart.csv"

class BruteForce:
    def __init__(self, database, support = 0.5, confidence = 0.5) -> None:
        self.database = database
        cd = CreateDataset(self.database)
        self.items = cd.extract_items()
        self.transactions = cd.extract_transac()
        self.support = support
        self.confidence = confidence
        self.prepare_itemsets_recs()
        
    def show_items_transacs(self):    
        print("\n\nThe individual items present in the database:")
        for i in range(self.items.shape[0]):
            print(f"{i+1}. {self.items.iloc[i,1]}")
        print("\nAll the transactions in the database:")
        for i in range(self.transactions.shape[0]):
            print(f"TID {self.transactions.iloc[i, 0]}: {self.transactions.iloc[i,1]}")
        print("\n\n")

    def prepare_itemsets_recs(self):  
        '''Preparing single itemsets and transactions record for each individual transaction from the pandas dataframe'''
        self.itemsets = self.items.iloc[:, 1].to_list()
        self.transac_rec = {}
        for i in range(self.transactions.shape[0]):
            id, trans = self.transactions.iloc[i, 0], self.transactions.iloc[i,1]
            self.transac_rec[id] = trans.split(', ')
        # print(self.itemsets)

    def get_support(self, combos=None):
        '''returning a dictionary containing items whose frequency is greater than or equal to the min support defined by user'''
        freq = {}
        l = self.transactions.shape[0]
        if combos:
            for combo in combos:
                for vals in self.transac_rec.values():
                    if all(item in vals for item in combo):
                        freq[combo] = (freq.get(combo, 0) + 1)
                freq[combo] = round(freq.get(combo, 0)/l,2)
        else:
            for i in self.itemsets:
                for vals in self.transac_rec.values():
                    if i in vals:
                        freq[(i,)] = (freq.get((i,), 0) + 1)
                freq[(i,)] = round(freq.get((i,), 0)/l,2)
        temp = deepcopy(freq)
        for i in temp.keys():
            if freq[i] < self.support:
                freq.pop(i)   # Popping out the itemsets whose support is lower than the user defined min support
        return freq

    def gen_freq_sets(self):
        '''Generating all frequent itemsets'''
        freq = self.get_support()
        max_freq = max(freq.values()) if len(freq.values()) >0 else 0
        self.freq_itemsets = freq
        k = 1
        while(max_freq >= self.support):
            combos = list(itertools.combinations(self.itemsets, k+1))
            freq = self.get_support(combos)
            if not freq: 
                max_freq = 0
                break
            max_freq = max(freq.values())
            self.freq_itemsets.update(freq)
            k += 1

    def gen_asso_rules(self):
        self.gen_freq_sets()
        all_combos = {key:val for key, val in self.freq_itemsets.items() if len(key) > 1}
        asso_rules = {}
        for combo in all_combos:
            asso_list = []
            for l in range(len(combo)-1):
                asso_list.extend(itertools.combinations(combo, l+1)) 
            combo_supp = all_combos[combo]
            for i in asso_list:
                others = tuple(set(combo)- set(i))
                if i in self.freq_itemsets.keys():
                    conf = round(combo_supp/self.freq_itemsets[i],2)
                    if conf >= self.confidence:
                        asso_rules[(i,combo)] = [others, combo_supp, conf]
                if others in self.freq_itemsets.keys():
                    rev_conf = round(combo_supp/self.freq_itemsets[others],2)
                    if rev_conf >= self.confidence:
                        asso_rules[(others, combo)] = [i, combo_supp, rev_conf]
        return self.freq_itemsets, asso_rules
    
    def testing(self):
        transacs = [tuple(val) for val in self.transac_rec.values()]
        start_time_ap = time.time()
        itemsets, rules = apriori(transacs, min_support=self.support, min_confidence=self.confidence)
        end_time_ap = time.time()
        counter = 0
        print("-----LIBRARY APRIORI ALGORITHM-----")
        print(f"\nUsing library apriori algorithm we get itemsets --> {itemsets} \n")
        print("Using Library Apriori the association rules are as follows (with support and confidence) using Brute Force:")
        for rule in rules:
             counter += 1
             print(f"{counter}. {rule}")
        print("\n\n")
        print("-----LIBRARY FPT ALGORITHM-----")
        start_time_fp = time.time()
        freqItemSet, rules = fpgrowth(transacs, self.support, self.confidence)
        end_time_fp = time.time()
        print(f"\nUsing library FPT algorithm we get itemsets --> {freqItemSet} \n")
        print("Using Library FPT the association rules are as follows (with support and confidence) using Brute Force:")
        counter = 0
        for rule in rules:
             counter += 1
             print(f"{counter}. {rule}")
        print("\n\n")
        exec_time_ap = end_time_ap - start_time_ap
        exec_time_fp = end_time_fp - start_time_fp
        return exec_time_ap, exec_time_fp

n = 0
while n != "exit":
    print("Welcome to Association rule mining. Please select one of the following databases to find association rules from:")
    database = [AMAZON, BESTBUY, KMART, NIKE, WALMART]
    for i in range(len(database)):
        print(f"{i}.: {database[i]}")
    n = input(f"Your choice (type and enter 'exit' to exit): ")
    if n == 'exit': break
    try:
        n = int(n)
        if n < 0 or n > 4:
            print("Invalid choice. Please try again!")
            continue
    except ValueError:
        print("Invalid input. Please input a number!")
        continue
    db_of_choice = database[n]
    try:
        supp = float(input("Choose a support from 0.01 to 1 (e.g. 0.5) where 0.01 means 1 percent and 1 means 100 percent support: "))
        conf = float(input("Choose a confidence from 0.01 to 1 (e.g. 0.5) where 0.01 means 1 percent and 1 means 100 percent confidence: "))
        if (supp > 1 or supp<=0) or (conf>1 or conf<=0): 
            print("Wrong support or confidence. Please try again.")
            continue
    except ValueError:
        print("Invalid input. Please input a number!")
        continue
    bf = BruteForce(db_of_choice, supp, conf)
    start_time = time.time()
    freq_itemsets, asso_rules = bf.gen_asso_rules()
    end_time = time.time()
    bf.show_items_transacs()
    print("-----BRUTE FORCE ALGORITHM-----")
    print(f"\nUsing Brute Force we get itemsets --> {freq_itemsets}\n")
    print("Using Brute Force the association rules are as follows (with support and confidence) using Brute Force:")
    counter = 0
    for key, val in asso_rules.items():
        counter += 1
        print(f"{counter}. [{key[0]} --> {val[0]}] : Support = {val[1]*100}%; Confidence = {val[2]*100}%")
    print("\n\n")
    exec_time = end_time - start_time
    exec_time_ap, exec_time_fp = bf.testing()
    print(f"Execution time for Brute Force: {exec_time} \nExecution time for Library Apriori: {exec_time_ap} \nExecution time for Library FPT: {exec_time_fp}")
    print("\n\n")
print("Thank you, have a nice day!")
# Out:
# Welcome to Association rule mining. Please select one of the following databases to find association rules from:
# 0.: Amazon.csv
# 1.: BestBuy.csv
# 2.: Kmart.csv
# 3.: Nike.csv
# 4.: Walmart.csv
# Your choice (type and enter 'exit' to exit): 2
# Choose a support from 0.01 to 1 (e.g. 0.5) where 0.01 means 1 percent and 1 means 100 percent support: 0.4
# Choose a confidence from 0.01 to 1 (e.g. 0.5) where 0.01 means 1 percent and 1 means 100 percent confidence: 0.74
#
#
# The individual items present in the database:
# 1. Quilts
# 2. Bedspreads
# 3. Decorative Pillows
# 4. Bed Skirts
# 5. Sheets
# 6. Shams
# 7. Bedding Collections
# 8. Kids Bedding
# 9. Embroidered Bedspread
# 10. Towels
#
# All the transactions in the database:
# TID Trans1: Decorative Pillows, Quilts, Embroidered Bedspread
# TID Trans2: Embroidered Bedspread, Shams, Kids Bedding, Bedding Collections, Bed Skirts, Bedspreads, Sheets
# TID Trans3: Decorative Pillows, Quilts, Embroidered Bedspread, Shams, Kids Bedding, Bedding Collections
# TID Trans4: Kids Bedding, Bedding Collections, Sheets, Bedspreads, Bed Skirts
# TID Trans5: Decorative Pillows, Kids Bedding, Bedding Collections, Sheets, Bed Skirts, Bedspreads
# TID Trans6: Bedding Collections, Bedspreads, Bed Skirts, Sheets, Shams, Kids Bedding
# TID Trans7: Decorative Pillows, Quilts
# TID Trans8: Decorative Pillows, Quilts, Embroidered Bedspread
# TID Trans9: Bedspreads, Bed Skirts, Shams, Kids Bedding, Sheets
# TID Trans10: Quilts, Embroidered Bedspread, Bedding Collections
# TID Trans11: Bedding Collections, Bedspreads, Bed Skirts, Kids Bedding, Shams, Sheets
# TID Trans12: Decorative Pillows, Quilts
# TID Trans13: Embroidered Bedspread, Shams
# TID Trans14: Sheets, Shams, Bed Skirts, Kids Bedding
# TID Trans15: Decorative Pillows, Quilts
# TID Trans16: Decorative Pillows, Kids Bedding, Bed Skirts, Shams
# TID Trans17: Decorative Pillows, Shams, Bed Skirts
# TID Trans18: Quilts, Sheets, Kids Bedding
# TID Trans19: Shams, Bed Skirts, Kids Bedding, Sheets
# TID Trans20: Decorative Pillows, Bedspreads, Shams, Sheets, Bed Skirts, Kids Bedding
#
#
#
# -----BRUTE FORCE ALGORITHM-----
#
# Using Brute Force we get itemsets --> {('Quilts',): 0.4, ('Decorative Pillows',): 0.5, ('Bed Skirts',): 0.55, ('Sheets',): 0.5, ('Shams',): 0.55, ('Kids Bedding',): 0.6, ('Bed Skirts', 'Sheets'): 0.45, ('Bed Skirts', 'Shams'): 0.45, ('Bed Skirts', 'Kids Bedding'): 0.5, ('Sheets', 'Kids Bedding'): 0.5, ('Shams', 'Kids Bedding'): 0.45, ('Bed Skirts', 'Sheets', 'Kids Bedding'): 0.45, ('Bed Skirts', 'Shams', 'Kids Bedding'): 0.4}
#
# Using Brute Force the association rules are as follows (with support and confidence) using Brute Force:
# 1. [('Bed Skirts',) --> ('Sheets',)] : Support = 45.0%; Confidence = 82.0%
# 2. [('Sheets',) --> ('Bed Skirts',)] : Support = 45.0%; Confidence = 90.0%
# 3. [('Bed Skirts',) --> ('Shams',)] : Support = 45.0%; Confidence = 82.0%
# 4. [('Shams',) --> ('Bed Skirts',)] : Support = 45.0%; Confidence = 82.0%
# 5. [('Bed Skirts',) --> ('Kids Bedding',)] : Support = 50.0%; Confidence = 91.0%
# 6. [('Kids Bedding',) --> ('Bed Skirts',)] : Support = 50.0%; Confidence = 83.0%
# 7. [('Sheets',) --> ('Kids Bedding',)] : Support = 50.0%; Confidence = 100.0%
# 8. [('Kids Bedding',) --> ('Sheets',)] : Support = 50.0%; Confidence = 83.0%
# 9. [('Shams',) --> ('Kids Bedding',)] : Support = 45.0%; Confidence = 82.0%
# 10. [('Kids Bedding',) --> ('Shams',)] : Support = 45.0%; Confidence = 75.0%
# 11. [('Bed Skirts',) --> ('Sheets', 'Kids Bedding')] : Support = 45.0%; Confidence = 82.0%
# 12. [('Sheets', 'Kids Bedding') --> ('Bed Skirts',)] : Support = 45.0%; Confidence = 90.0%
# 13. [('Sheets',) --> ('Bed Skirts', 'Kids Bedding')] : Support = 45.0%; Confidence = 90.0%
# 14. [('Kids Bedding',) --> ('Bed Skirts', 'Sheets')] : Support = 45.0%; Confidence = 75.0%
# 15. [('Bed Skirts', 'Sheets') --> ('Kids Bedding',)] : Support = 45.0%; Confidence = 100.0%
# 16. [('Bed Skirts', 'Kids Bedding') --> ('Sheets',)] : Support = 45.0%; Confidence = 90.0%
# 17. [('Shams', 'Kids Bedding') --> ('Bed Skirts',)] : Support = 40.0%; Confidence = 89.0%
# 18. [('Bed Skirts', 'Shams') --> ('Kids Bedding',)] : Support = 40.0%; Confidence = 89.0%
# 19. [('Bed Skirts', 'Kids Bedding') --> ('Shams',)] : Support = 40.0%; Confidence = 80.0%
#
#
#
# -----LIBRARY APRIORI ALGORITHM-----
#
# Using library apriori algorithm we get itemsets --> {1: {('Decorative Pillows',): 10, ('Quilts',): 8, ('Shams',): 11, ('Kids Bedding',): 12, ('Bed Skirts',): 11, ('Sheets',): 10}, 2: {('Bed Skirts', 'Kids Bedding'): 10, ('Bed Skirts', 'Shams'): 9, ('Bed Skirts', 'Sheets'): 9, ('Kids Bedding', 'Shams'): 9, ('Kids Bedding', 'Sheets'): 10}, 3: {('Bed Skirts', 'Kids Bedding', 'Shams'): 8, ('Bed Skirts', 'Kids Bedding', 'Sheets'): 9}}
#
# Using Library Apriori the association rules are as follows (with support and confidence) using Brute Force:
# 1. {Kids Bedding} -> {Bed Skirts} (conf: 0.833, supp: 0.500, lift: 1.515, conv: 2.700)
# 2. {Bed Skirts} -> {Kids Bedding} (conf: 0.909, supp: 0.500, lift: 1.515, conv: 4.400)
# 3. {Shams} -> {Bed Skirts} (conf: 0.818, supp: 0.450, lift: 1.488, conv: 2.475)
# 4. {Bed Skirts} -> {Shams} (conf: 0.818, supp: 0.450, lift: 1.488, conv: 2.475)
# 5. {Sheets} -> {Bed Skirts} (conf: 0.900, supp: 0.450, lift: 1.636, conv: 4.500)
# 6. {Bed Skirts} -> {Sheets} (conf: 0.818, supp: 0.450, lift: 1.636, conv: 2.750)
# 7. {Shams} -> {Kids Bedding} (conf: 0.818, supp: 0.450, lift: 1.364, conv: 2.200)
# 8. {Kids Bedding} -> {Shams} (conf: 0.750, supp: 0.450, lift: 1.364, conv: 1.800)
# 9. {Sheets} -> {Kids Bedding} (conf: 1.000, supp: 0.500, lift: 1.667, conv: 400000000.000)
# 10. {Kids Bedding} -> {Sheets} (conf: 0.833, supp: 0.500, lift: 1.667, conv: 3.000)
# 11. {Kids Bedding, Shams} -> {Bed Skirts} (conf: 0.889, supp: 0.400, lift: 1.616, conv: 4.050)
# 12. {Bed Skirts, Shams} -> {Kids Bedding} (conf: 0.889, supp: 0.400, lift: 1.481, conv: 3.600)
# 13. {Bed Skirts, Kids Bedding} -> {Shams} (conf: 0.800, supp: 0.400, lift: 1.455, conv: 2.250)
# 14. {Kids Bedding, Sheets} -> {Bed Skirts} (conf: 0.900, supp: 0.450, lift: 1.636, conv: 4.500)
# 15. {Bed Skirts, Sheets} -> {Kids Bedding} (conf: 1.000, supp: 0.450, lift: 1.667, conv: 400000000.000)
# 16. {Bed Skirts, Kids Bedding} -> {Sheets} (conf: 0.900, supp: 0.450, lift: 1.800, conv: 5.000)
# 17. {Sheets} -> {Bed Skirts, Kids Bedding} (conf: 0.900, supp: 0.450, lift: 1.800, conv: 5.000)
# 18. {Kids Bedding} -> {Bed Skirts, Sheets} (conf: 0.750, supp: 0.450, lift: 1.667, conv: 2.200)
# 19. {Bed Skirts} -> {Kids Bedding, Sheets} (conf: 0.818, supp: 0.450, lift: 1.636, conv: 2.750)
#
#
#
# -----LIBRARY FPT ALGORITHM-----
#
# Using library FPT algorithm we get itemsets --> [{'Quilts'}, {'Decorative Pillows'}, {'Sheets'}, {'Sheets', 'Bed Skirts'}, {'Sheets', 'Kids Bedding', 'Bed Skirts'}, {'Sheets', 'Kids Bedding'}, {'Shams'}, {'Shams', 'Kids Bedding'}, {'Bed Skirts'}, {'Kids Bedding', 'Bed Skirts'}, {'Kids Bedding'}]
#
# Using Library FPT the association rules are as follows (with support and confidence) using Brute Force:
# 1. [{'Sheets'}, {'Bed Skirts'}, 0.9]
# 2. [{'Bed Skirts'}, {'Sheets'}, 0.8181818181818182]
# 3. [{'Sheets'}, {'Kids Bedding', 'Bed Skirts'}, 0.9]
# 4. [{'Kids Bedding'}, {'Sheets', 'Bed Skirts'}, 0.75]
# 5. [{'Bed Skirts'}, {'Sheets', 'Kids Bedding'}, 0.8181818181818182]
# 6. [{'Sheets', 'Kids Bedding'}, {'Bed Skirts'}, 0.9]
# 7. [{'Sheets', 'Bed Skirts'}, {'Kids Bedding'}, 1.0]
# 8. [{'Kids Bedding', 'Bed Skirts'}, {'Sheets'}, 0.9]
# 9. [{'Sheets'}, {'Kids Bedding'}, 1.0]
# 10. [{'Kids Bedding'}, {'Sheets'}, 0.8333333333333334]
# 11. [{'Shams'}, {'Kids Bedding'}, 0.8181818181818182]
# 12. [{'Kids Bedding'}, {'Shams'}, 0.75]
# 13. [{'Kids Bedding'}, {'Bed Skirts'}, 0.8333333333333334]
# 14. [{'Bed Skirts'}, {'Kids Bedding'}, 0.9090909090909091]
#
#
#
# Execution time for Brute Force: 0.00726771354675293
# Execution time for Library Apriori: 0.0
# Execution time for Library FPT: 0.0012471675872802734
#
#
#
# Welcome to Association rule mining. Please select one of the following databases to find association rules from:
# 0.: Amazon.csv
# 1.: BestBuy.csv
# 2.: Kmart.csv
# 3.: Nike.csv
# 4.: Walmart.csv
# Your choice (type and enter 'exit' to exit): 3
# Choose a support from 0.01 to 1 (e.g. 0.5) where 0.01 means 1 percent and 1 means 100 percent support: 55
# Choose a confidence from 0.01 to 1 (e.g. 0.5) where 0.01 means 1 percent and 1 means 100 percent confidence: 82
# Wrong support or confidence. Please try again.
# Welcome to Association rule mining. Please select one of the following databases to find association rules from:
# 0.: Amazon.csv
# 1.: BestBuy.csv
# 2.: Kmart.csv
# 3.: Nike.csv
# 4.: Walmart.csv
# Your choice (type and enter 'exit' to exit): 3
# Choose a support from 0.01 to 1 (e.g. 0.5) where 0.01 means 1 percent and 1 means 100 percent support: 0.55
# Choose a confidence from 0.01 to 1 (e.g. 0.5) where 0.01 means 1 percent and 1 means 100 percent confidence: 0.82
#
#
# The individual items present in the database:
# 1. Running Shoe
# 2. Soccer Shoe
# 3. Socks
# 4. Swimming Shirt
# 5. Dry Fit V-Nick
# 6. Rash Guard
# 7. Sweatshirts
# 8. Hoodies
# 9. Tech Pants
# 10. Modern Pants
#
# All the transactions in the database:
# TID Trans1: Running Shoe, Socks, Sweatshirts, Modern Pants
# TID Trans2: Running Shoe, Socks, Sweatshirts
# TID Trans3: Running Shoe, Socks, Sweatshirts, Modern Pants
# TID Trans4: Running Shoe, Sweatshirts, Modern Pants
# TID Trans5: Running Shoe, Socks, Sweatshirts, Modern Pants, Soccer Shoe
# TID Trans6: Running Shoe, Socks, Sweatshirts
# TID Trans7: Running Shoe, Socks, Sweatshirts, Modern Pants, Tech Pants, Rash Guard, Hoodies
# TID Trans8: Swimming Shirt, Socks, Sweatshirts
# TID Trans9: Swimming Shirt, Rash Guard, Dry Fit V-Nick, Hoodies, Tech Pants
# TID Trans10: Swimming Shirt, Rash Guard, Dry
# TID Trans11: Swimming Shirt, Rash Guard, Dry Fit V-Nick
# TID Trans12: Running Shoe, Swimming Shirt, Socks, Sweatshirts, Modern Pants, Soccer Shoe, Rash Guard, Hoodies, Tech Pants, Dry Fit V-Nick
# TID Trans13: Running Shoe, Swimming Shirt, Socks, Sweatshirts, Modern Pants, Soccer Shoe, Rash Guard, Tech Pants, Dry Fit V-Nick, Hoodies
# TID Trans14: Running Shoe, Swimming Shirt, Rash Guard, Tech Pants, Hoodies, Dry Fit V-Nick
# TID Trans15: Running Shoe, Swimming Shirt, Socks, Sweatshirts, Modern Pants, Dry Fit V-Nick, Rash Guard, Tech Pants
# TID Trans16: Swimming Shirt, Soccer Shoe, Hoodies, Dry Fit V-Nick, Tech Pants, Rash Guard
# TID Trans17: Running Shoe, Socks
# TID Trans18: Socks, Sweatshirts, Modern Pants, Soccer Shoe, Hoodies, Rash Guard, Tech Pants, Dry Fit V-Nick
# TID Trans19: Running Shoe, Swimming Shirt, Rash Guard
# TID Trans20: Running Shoe, Swimming Shirt, Socks, Sweatshirts, Modern Pants, Soccer Shoe, Hoodies, Tech Pants, Rash Guard, Dry Fit V-Nick
#
#
#
# -----BRUTE FORCE ALGORITHM-----
#
# Using Brute Force we get itemsets --> {('Running Shoe',): 0.7, ('Socks',): 0.65, ('Swimming Shirt',): 0.55, ('Rash Guard',): 0.6, ('Sweatshirts',): 0.65, ('Running Shoe', 'Socks'): 0.55, ('Running Shoe', 'Sweatshirts'): 0.55, ('Socks', 'Sweatshirts'): 0.6}
#
# Using Brute Force the association rules are as follows (with support and confidence) using Brute Force:
# 1. [('Socks',) --> ('Running Shoe',)] : Support = 55.00000000000001%; Confidence = 85.0%
# 2. [('Sweatshirts',) --> ('Running Shoe',)] : Support = 55.00000000000001%; Confidence = 85.0%
# 3. [('Socks',) --> ('Sweatshirts',)] : Support = 60.0%; Confidence = 92.0%
# 4. [('Sweatshirts',) --> ('Socks',)] : Support = 60.0%; Confidence = 92.0%
#
#
#
# -----LIBRARY APRIORI ALGORITHM-----
#
# Using library apriori algorithm we get itemsets --> {1: {('Running Shoe',): 14, ('Socks',): 13, ('Sweatshirts',): 13, ('Rash Guard',): 12, ('Swimming Shirt',): 11}, 2: {('Running Shoe', 'Socks'): 11, ('Running Shoe', 'Sweatshirts'): 11, ('Socks', 'Sweatshirts'): 12}}
#
# Using Library Apriori the association rules are as follows (with support and confidence) using Brute Force:
# 1. {Socks} -> {Running Shoe} (conf: 0.846, supp: 0.550, lift: 1.209, conv: 1.950)
# 2. {Sweatshirts} -> {Running Shoe} (conf: 0.846, supp: 0.550, lift: 1.209, conv: 1.950)
# 3. {Sweatshirts} -> {Socks} (conf: 0.923, supp: 0.600, lift: 1.420, conv: 4.550)
# 4. {Socks} -> {Sweatshirts} (conf: 0.923, supp: 0.600, lift: 1.420, conv: 4.550)
#
#
#
# -----LIBRARY FPT ALGORITHM-----
#
# Using library FPT algorithm we get itemsets --> [{'Swimming Shirt'}, {'Rash Guard'}, {'Socks'}, {'Socks', 'Running Shoe'}, {'Sweatshirts'}, {'Sweatshirts', 'Running Shoe'}, {'Socks', 'Sweatshirts'}, {'Running Shoe'}]
#
# Using Library FPT the association rules are as follows (with support and confidence) using Brute Force:
# 1. [{'Socks'}, {'Running Shoe'}, 0.8461538461538461]
# 2. [{'Sweatshirts'}, {'Running Shoe'}, 0.8461538461538461]
# 3. [{'Socks'}, {'Sweatshirts'}, 0.9230769230769231]
# 4. [{'Sweatshirts'}, {'Socks'}, 0.9230769230769231]
#
#
#
# Execution time for Brute Force: 0.0034246444702148438
# Execution time for Library Apriori: 0.0
# Execution time for Library FPT: 0.0010073184967041016
#
#
#
# Welcome to Association rule mining. Please select one of the following databases to find association rules from:
# 0.: Amazon.csv
# 1.: BestBuy.csv
# 2.: Kmart.csv
# 3.: Nike.csv
# 4.: Walmart.csv
# Your choice (type and enter 'exit' to exit): exit
# Thank you, have a nice day!
